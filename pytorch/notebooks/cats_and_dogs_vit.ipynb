# %% [markdown]
# # Visual Transformer with Linformer
#
# Training Visual Transformer on *Dogs vs Cats Data*
#
# * Dogs vs. Cats Redux: Kernels Edition - https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition
# * Base Code - https://www.kaggle.com/reukki/pytorch-cnn-tutorial-with-cats-and-dogs/
# * Effecient Attention Implementation - https://github.com/lucidrains/vit-pytorch#efficient-attention

# %%
# %pip -q install vit_pytorch linformer
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade tqdm

# %% [markdown]
# ## Import Libraries

# %%
from __future__ import print_function

import glob
from itertools import chain
import os
import random
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from linformer import Linformer
from PIL import Image
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from tqdm.notebook import tqdm

from vit_pytorch.efficient import ViT

# %%
print(f"Torch: {torch.__version__}")
torch.cuda.is_available()
# Out:
# Torch: 1.10.0+cpu
# False

# %%
# Training settings
batch_size = 64
epochs = 20
lr = 3e-5
gamma = 0.7
seed = 42

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed_everything(seed)

# %%
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# ## Load Data

# %%
os.makedirs('data', exist_ok=True)

# %%
train_dir = 'data/train'
test_dir = 'data/test'

# %%
with zipfile.ZipFile('train.zip') as train_zip:
    train_zip.extractall('data')
    
with zipfile.ZipFile('test.zip') as test_zip:
    test_zip.extractall('data')

# %%
train_list = glob.glob(os.path.join(train_dir,'*.jpg'))
test_list = glob.glob(os.path.join(test_dir, '*.jpg'))

# %%
print(f"Train Data: {len(train_list)}")
print(f"Test Data: {len(test_list)}")
# Out:
# Train Data: 25000
# Test Data: 12500

# %%
train_list
# Out:
# ['data/train\\cat.0.jpg',
#  'data/train\\cat.1.jpg',
#  'data/train\\cat.10.jpg',
#  'data/train\\cat.100.jpg',
#  'data/train\\cat.1000.jpg',
#  'data/train\\cat.10000.jpg',
#  'data/train\\cat.10001.jpg',
#  'data/train\\cat.10002.jpg',
#  'data/train\\cat.10003.jpg',
#  'data/train\\cat.10004.jpg',
#  'data/train\\cat.10005.jpg',
#  'data/train\\cat.10006.jpg',
#  'data/train\\cat.10007.jpg',
#  'data/train\\cat.10008.jpg',
#  'data/train\\cat.10009.jpg',
#  'data/train\\cat.1001.jpg',
#  'data/train\\cat.10010.jpg',
#  'data/train\\cat.10011.jpg',
#  'data/train\\cat.10012.jpg',
#  'data/train\\cat.10013.jpg',
#  'data/train\\cat.10014.jpg',
#  'data/train\\cat.10015.jpg',
#  'data/train\\cat.10016.jpg',
#  'data/train\\cat.10017.jpg',
#  'data/train\\cat.10018.jpg',
#  'data/train\\cat.10019.jpg',
#  'data/train\\cat.1002.jpg',
#  'data/train\\cat.10020.jpg',
#  'data/train\\cat.10021.jpg',
#  'data/train\\cat.10022.jpg',
#  'data/train\\cat.10023.jpg',
#  'data/train\\cat.10024.jpg',
#  'data/train\\cat.10025.jpg',
#  'data/train\\cat.10026.jpg',
#  'data/train\\cat.10027.jpg',
#  'data/train\\cat.10028.jpg',
#  'data/train\\cat.10029.jpg',
#  'data/train\\cat.1003.jpg',
#  'data/train\\cat.10030.jpg',
#  'data/train\\cat.10031.jpg',
#  'data/train\\cat.10032.jpg',
#  'data/train\\cat.10033.jpg',
#  'data/train\\cat.10034.jpg',
#  'data/train\\cat.10035.jpg',
#  'data/train\\cat.10036.jpg',
#  'data/train\\cat.10037.jpg',
#  'data/train\\cat.10038.jpg',
#  'data/train\\cat.10039.jpg',
#  'data/train\\cat.1004.jpg',
#  'data/train\\cat.10040.jpg',
#  'data/train\\cat.10041.jpg',
#  'data/train\\cat.10042.jpg',
#  'data/train\\cat.10043.jpg',
#  'data/train\\cat.10044.jpg',
#  'data/train\\cat.10045.jpg',
#  'data/train\\cat.10046.jpg',
#  'data/train\\cat.10047.jpg',
#  'data/train\\cat.10048.jpg',
#  'data/train\\cat.10049.jpg',
#  'data/train\\cat.1005.jpg',
#  'data/train\\cat.10050.jpg',
#  'data/train\\cat.10051.jpg',
#  'data/train\\cat.10052.jpg',
#  'data/train\\cat.10053.jpg',
#  'data/train\\cat.10054.jpg',
#  'data/train\\cat.10055.jpg',
#  'data/train\\cat.10056.jpg',
#  'data/train\\cat.10057.jpg',
#  'data/train\\cat.10058.jpg',
#  'data/train\\cat.10059.jpg',
#  'data/train\\cat.1006.jpg',
#  'data/train\\cat.10060.jpg',
#  'data/train\\cat.10061.jpg',
#  'data/train\\cat.10062.jpg',
#  'data/train\\cat.10063.jpg',
#  'data/train\\cat.10064.jpg',
#  'data/train\\cat.10065.jpg',
#  'data/train\\cat.10066.jpg',
#  'data/train\\cat.10067.jpg',
#  'data/train\\cat.10068.jpg',
#  'data/train\\cat.10069.jpg',
#  'data/train\\cat.1007.jpg',
#  'data/train\\cat.10070.jpg',
#  'data/train\\cat.10071.jpg',
#  'data/train\\cat.10072.jpg',
#  'data/train\\cat.10073.jpg',
#  'data/train\\cat.10074.jpg',
#  'data/train\\cat.10075.jpg',
#  'data/train\\cat.10076.jpg',
#  'data/train\\cat.10077.jpg',
#  'data/train\\cat.10078.jpg',
#  'data/train\\cat.10079.jpg',
#  'data/train\\cat.1008.jpg',
#  'data/train\\cat.10080.jpg',
#  'data/train\\cat.10081.jpg',
#  'data/train\\cat.10082.jpg',
#  'data/train\\cat.10083.jpg',
#  'data/train\\cat.10084.jpg',
#  'data/train\\cat.10085.jpg',
#  'data/train\\cat.10086.jpg',
#  'data/train\\cat.10087.jpg',
#  'data/train\\cat.10088.jpg',
#  'data/train\\cat.10089.jpg',
#  'data/train\\cat.1009.jpg',
#  'data/train\\cat.10090.jpg',
#  'data/train\\cat.10091.jpg',
#  'data/train\\cat.10092.jpg',
#  'data/train\\cat.10093.jpg',
#  'data/train\\cat.10094.jpg',
#  'data/train\\cat.10095.jpg',
#  'data/train\\cat.10096.jpg',
#  'data/train\\cat.10097.jpg',
#  'data/train\\cat.10098.jpg',
#  'data/train\\cat.10099.jpg',
#  'data/train\\cat.101.jpg',
#  'data/train\\cat.1010.jpg',
#  'data/train\\cat.10100.jpg',
#  'data/train\\cat.10101.jpg',
#  'data/train\\cat.10102.jpg',
#  'data/train\\cat.10103.jpg',
#  'data/train\\cat.10104.jpg',
#  'data/train\\cat.10105.jpg',
#  'data/train\\cat.10106.jpg',
#  'data/train\\cat.10107.jpg',
#  'data/train\\cat.10108.jpg',
#  'data/train\\cat.10109.jpg',
#  'data/train\\cat.1011.jpg',
#  'data/train\\cat.10110.jpg',
#  'data/train\\cat.10111.jpg',
#  'data/train\\cat.10112.jpg',
#  'data/train\\cat.10113.jpg',
#  'data/train\\cat.10114.jpg',
#  'data/train\\cat.10115.jpg',
#  'data/train\\cat.10116.jpg',
#  'data/train\\cat.10117.jpg',
#  'data/train\\cat.10118.jpg',
#  'data/train\\cat.10119.jpg',
#  'data/train\\cat.1012.jpg',
#  'data/train\\cat.10120.jpg',
#  'data/train\\cat.10121.jpg',
#  'data/train\\cat.10122.jpg',
#  'data/train\\cat.10123.jpg',
#  'data/train\\cat.10124.jpg',
#  'data/train\\cat.10125.jpg',
#  'data/train\\cat.10126.jpg',
#  'data/train\\cat.10127.jpg',
#  'data/train\\cat.10128.jpg',
#  'data/train\\cat.10129.jpg',
#  'data/train\\cat.1013.jpg',
#  'data/train\\cat.10130.jpg',
#  'data/train\\cat.10131.jpg',
#  'data/train\\cat.10132.jpg',
#  'data/train\\cat.10133.jpg',
#  'data/train\\cat.10134.jpg',
#  'data/train\\cat.10135.jpg',
#  'data/train\\cat.10136.jpg',
#  'data/train\\cat.10137.jpg',
#  'data/train\\cat.10138.jpg',
#  'data/train\\cat.10139.jpg',
#  'data/train\\cat.1014.jpg',
#  'data/train\\cat.10140.jpg',
#  'data/train\\cat.10141.jpg',
#  'data/train\\cat.10142.jpg',
#  'data/train\\cat.10143.jpg',
#  'data/train\\cat.10144.jpg',
#  'data/train\\cat.10145.jpg',
#  'data/train\\cat.10146.jpg',
#  'data/train\\cat.10147.jpg',
#  'data/train\\cat.10148.jpg',
#  'data/train\\cat.10149.jpg',
#  'data/train\\cat.1015.jpg',
#  'data/train\\cat.10150.jpg',
#  'data/train\\cat.10151.jpg',
#  'data/train\\cat.10152.jpg',
#  'data/train\\cat.10153.jpg',
#  'data/train\\cat.10154.jpg',
#  'data/train\\cat.10155.jpg',
#  'data/train\\cat.10156.jpg',
#  'data/train\\cat.10157.jpg',
#  'data/train\\cat.10158.jpg',
#  'data/train\\cat.10159.jpg',
#  'data/train\\cat.1016.jpg',
#  'data/train\\cat.10160.jpg',
#  'data/train\\cat.10161.jpg',
#  'data/train\\cat.10162.jpg',
#  'data/train\\cat.10163.jpg',
#  'data/train\\cat.10164.jpg',
#  'data/train\\cat.10165.jpg',
#  'data/train\\cat.10166.jpg',
#  'data/train\\cat.10167.jpg',
#  'data/train\\cat.10168.jpg',
#  'data/train\\cat.10169.jpg',
#  'data/train\\cat.1017.jpg',
#  'data/train\\cat.10170.jpg',
#  'data/train\\cat.10171.jpg',
#  'data/train\\cat.10172.jpg',
#  'data/train\\cat.10173.jpg',
#  'data/train\\cat.10174.jpg',
#  'data/train\\cat.10175.jpg',
#  'data/train\\cat.10176.jpg',
#  'data/train\\cat.10177.jpg',
#  'data/train\\cat.10178.jpg',
#  'data/train\\cat.10179.jpg',
#  'data/train\\cat.1018.jpg',
#  'data/train\\cat.10180.jpg',
#  'data/train\\cat.10181.jpg',
#  'data/train\\cat.10182.jpg',
#  'data/train\\cat.10183.jpg',
#  'data/train\\cat.10184.jpg',
#  'data/train\\cat.10185.jpg',
#  'data/train\\cat.10186.jpg',
#  'data/train\\cat.10187.jpg',
#  'data/train\\cat.10188.jpg',
#  'data/train\\cat.10189.jpg',
#  'data/train\\cat.1019.jpg',
#  'data/train\\cat.10190.jpg',
#  'data/train\\cat.10191.jpg',
#  'data/train\\cat.10192.jpg',
#  'data/train\\cat.10193.jpg',
#  'data/train\\cat.10194.jpg',
#  'data/train\\cat.10195.jpg',
#  'data/train\\cat.10196.jpg',
#  'data/train\\cat.10197.jpg',
#  'data/train\\cat.10198.jpg',
#  'data/train\\cat.10199.jpg',
#  'data/train\\cat.102.jpg',
#  'data/train\\cat.1020.jpg',
#  'data/train\\cat.10200.jpg',
#  'data/train\\cat.10201.jpg',
#  'data/train\\cat.10202.jpg',
#  'data/train\\cat.10203.jpg',
#  'data/train\\cat.10204.jpg',
#  'data/train\\cat.10205.jpg',
#  'data/train\\cat.10206.jpg',
#  'data/train\\cat.10207.jpg',
#  'data/train\\cat.10208.jpg',
#  'data/train\\cat.10209.jpg',
#  'data/train\\cat.1021.jpg',
#  'data/train\\cat.10210.jpg',
#  'data/train\\cat.10211.jpg',
#  'data/train\\cat.10212.jpg',
#  'data/train\\cat.10213.jpg',
#  'data/train\\cat.10214.jpg',
#  'data/train\\cat.10215.jpg',
#  'data/train\\cat.10216.jpg',
#  'data/train\\cat.10217.jpg',
#  'data/train\\cat.10218.jpg',
#  'data/train\\cat.10219.jpg',
#  'data/train\\cat.1022.jpg',
#  'data/train\\cat.10220.jpg',
#  'data/train\\cat.10221.jpg',
#  'data/train\\cat.10222.jpg',
#  'data/train\\cat.10223.jpg',
#  'data/train\\cat.10224.jpg',
#  'data/train\\cat.10225.jpg',
#  'data/train\\cat.10226.jpg',
#  'data/train\\cat.10227.jpg',
#  'data/train\\cat.10228.jpg',
#  'data/train\\cat.10229.jpg',
#  'data/train\\cat.1023.jpg',
#  'data/train\\cat.10230.jpg',
#  'data/train\\cat.10231.jpg',
#  'data/train\\cat.10232.jpg',
#  'data/train\\cat.10233.jpg',
#  'data/train\\cat.10234.jpg',
#  'data/train\\cat.10235.jpg',
#  'data/train\\cat.10236.jpg',
#  'data/train\\cat.10237.jpg',
#  'data/train\\cat.10238.jpg',
#  'data/train\\cat.10239.jpg',
#  'data/train\\cat.1024.jpg',
#  'data/train\\cat.10240.jpg',
#  'data/train\\cat.10241.jpg',
#  'data/train\\cat.10242.jpg',
#  'data/train\\cat.10243.jpg',
#  'data/train\\cat.10244.jpg',
#  'data/train\\cat.10245.jpg',
#  'data/train\\cat.10246.jpg',
#  'data/train\\cat.10247.jpg',
#  'data/train\\cat.10248.jpg',
#  'data/train\\cat.10249.jpg',
#  'data/train\\cat.1025.jpg',
#  'data/train\\cat.10250.jpg',
#  'data/train\\cat.10251.jpg',
#  'data/train\\cat.10252.jpg',
#  'data/train\\cat.10253.jpg',
#  'data/train\\cat.10254.jpg',
#  'data/train\\cat.10255.jpg',
#  'data/train\\cat.10256.jpg',
#  'data/train\\cat.10257.jpg',
#  'data/train\\cat.10258.jpg',
#  'data/train\\cat.10259.jpg',
#  'data/train\\cat.1026.jpg',
#  'data/train\\cat.10260.jpg',
#  'data/train\\cat.10261.jpg',
#  'data/train\\cat.10262.jpg',
#  'data/train\\cat.10263.jpg',
#  'data/train\\cat.10264.jpg',
#  'data/train\\cat.10265.jpg',
#  'data/train\\cat.10266.jpg',
#  'data/train\\cat.10267.jpg',
#  'data/train\\cat.10268.jpg',
#  'data/train\\cat.10269.jpg',
#  'data/train\\cat.1027.jpg',
#  'data/train\\cat.10270.jpg',
#  'data/train\\cat.10271.jpg',
#  'data/train\\cat.10272.jpg',
#  'data/train\\cat.10273.jpg',
#  'data/train\\cat.10274.jpg',
#  'data/train\\cat.10275.jpg',
#  'data/train\\cat.10276.jpg',
#  'data/train\\cat.10277.jpg',
#  'data/train\\cat.10278.jpg',
#  'data/train\\cat.10279.jpg',
#  'data/train\\cat.1028.jpg',
#  'data/train\\cat.10280.jpg',
#  'data/train\\cat.10281.jpg',
#  'data/train\\cat.10282.jpg',
#  'data/train\\cat.10283.jpg',
#  'data/train\\cat.10284.jpg',
#  'data/train\\cat.10285.jpg',
#  'data/train\\cat.10286.jpg',
#  'data/train\\cat.10287.jpg',
#  'data/train\\cat.10288.jpg',
#  'data/train\\cat.10289.jpg',
#  'data/train\\cat.1029.jpg',
#  'data/train\\cat.10290.jpg',
#  'data/train\\cat.10291.jpg',
#  'data/train\\cat.10292.jpg',
#  'data/train\\cat.10293.jpg',
#  'data/train\\cat.10294.jpg',
#  'data/train\\cat.10295.jpg',
#  'data/train\\cat.10296.jpg',
#  'data/train\\cat.10297.jpg',
#  'data/train\\cat.10298.jpg',
#  'data/train\\cat.10299.jpg',
#  'data/train\\cat.103.jpg',
#  'data/train\\cat.1030.jpg',
#  'data/train\\cat.10300.jpg',
#  'data/train\\cat.10301.jpg',
#  'data/train\\cat.10302.jpg',
#  'data/train\\cat.10303.jpg',
#  'data/train\\cat.10304.jpg',
#  'data/train\\cat.10305.jpg',
#  'data/train\\cat.10306.jpg',
#  'data/train\\cat.10307.jpg',
#  'data/train\\cat.10308.jpg',
#  'data/train\\cat.10309.jpg',
#  'data/train\\cat.1031.jpg',
#  'data/train\\cat.10310.jpg',
#  'data/train\\cat.10311.jpg',
#  'data/train\\cat.10312.jpg',
#  'data/train\\cat.10313.jpg',
#  'data/train\\cat.10314.jpg',
#  'data/train\\cat.10315.jpg',
#  'data/train\\cat.10316.jpg',
#  'data/train\\cat.10317.jpg',
#  'data/train\\cat.10318.jpg',
#  'data/train\\cat.10319.jpg',
#  'data/train\\cat.1032.jpg',
#  'data/train\\cat.10320.jpg',
#  'data/train\\cat.10321.jpg',
#  'data/train\\cat.10322.jpg',
#  'data/train\\cat.10323.jpg',
#  'data/train\\cat.10324.jpg',
#  'data/train\\cat.10325.jpg',
#  'data/train\\cat.10326.jpg',
#  'data/train\\cat.10327.jpg',
#  'data/train\\cat.10328.jpg',
#  'data/train\\cat.10329.jpg',
#  'data/train\\cat.1033.jpg',
#  'data/train\\cat.10330.jpg',
#  'data/train\\cat.10331.jpg',
#  'data/train\\cat.10332.jpg',
#  'data/train\\cat.10333.jpg',
#  'data/train\\cat.10334.jpg',
#  'data/train\\cat.10335.jpg',
#  'data/train\\cat.10336.jpg',
#  'data/train\\cat.10337.jpg',
#  'data/train\\cat.10338.jpg',
#  'data/train\\cat.10339.jpg',
#  'data/train\\cat.1034.jpg',
#  'data/train\\cat.10340.jpg',
#  'data/train\\cat.10341.jpg',
#  'data/train\\cat.10342.jpg',
#  'data/train\\cat.10343.jpg',
#  'data/train\\cat.10344.jpg',
#  'data/train\\cat.10345.jpg',
#  'data/train\\cat.10346.jpg',
#  'data/train\\cat.10347.jpg',
#  'data/train\\cat.10348.jpg',
#  'data/train\\cat.10349.jpg',
#  'data/train\\cat.1035.jpg',
#  'data/train\\cat.10350.jpg',
#  'data/train\\cat.10351.jpg',
#  'data/train\\cat.10352.jpg',
#  'data/train\\cat.10353.jpg',
#  'data/train\\cat.10354.jpg',
#  'data/train\\cat.10355.jpg',
#  'data/train\\cat.10356.jpg',
#  'data/train\\cat.10357.jpg',
#  'data/train\\cat.10358.jpg',
#  'data/train\\cat.10359.jpg',
#  'data/train\\cat.1036.jpg',
#  'data/train\\cat.10360.jpg',
#  'data/train\\cat.10361.jpg',
#  'data/train\\cat.10362.jpg',
#  'data/train\\cat.10363.jpg',
#  'data/train\\cat.10364.jpg',
#  'data/train\\cat.10365.jpg',
#  'data/train\\cat.10366.jpg',
#  'data/train\\cat.10367.jpg',
#  'data/train\\cat.10368.jpg',
#  'data/train\\cat.10369.jpg',
#  'data/train\\cat.1037.jpg',
#  'data/train\\cat.10370.jpg',
#  'data/train\\cat.10371.jpg',
#  'data/train\\cat.10372.jpg',
#  'data/train\\cat.10373.jpg',
#  'data/train\\cat.10374.jpg',
#  'data/train\\cat.10375.jpg',
#  'data/train\\cat.10376.jpg',
#  'data/train\\cat.10377.jpg',
#  'data/train\\cat.10378.jpg',
#  'data/train\\cat.10379.jpg',
#  'data/train\\cat.1038.jpg',
#  'data/train\\cat.10380.jpg',
#  'data/train\\cat.10381.jpg',
#  'data/train\\cat.10382.jpg',
#  'data/train\\cat.10383.jpg',
#  'data/train\\cat.10384.jpg',
#  'data/train\\cat.10385.jpg',
#  'data/train\\cat.10386.jpg',
#  'data/train\\cat.10387.jpg',
#  'data/train\\cat.10388.jpg',
#  'data/train\\cat.10389.jpg',
#  'data/train\\cat.1039.jpg',
#  'data/train\\cat.10390.jpg',
#  'data/train\\cat.10391.jpg',
#  'data/train\\cat.10392.jpg',
#  'data/train\\cat.10393.jpg',
#  'data/train\\cat.10394.jpg',
#  'data/train\\cat.10395.jpg',
#  'data/train\\cat.10396.jpg',
#  'data/train\\cat.10397.jpg',
#  'data/train\\cat.10398.jpg',
#  'data/train\\cat.10399.jpg',
#  'data/train\\cat.104.jpg',
#  'data/train\\cat.1040.jpg',
#  'data/train\\cat.10400.jpg',
#  'data/train\\cat.10401.jpg',
#  'data/train\\cat.10402.jpg',
#  'data/train\\cat.10403.jpg',
#  'data/train\\cat.10404.jpg',
#  'data/train\\cat.10405.jpg',
#  'data/train\\cat.10406.jpg',
#  'data/train\\cat.10407.jpg',
#  'data/train\\cat.10408.jpg',
#  'data/train\\cat.10409.jpg',
#  'data/train\\cat.1041.jpg',
#  'data/train\\cat.10410.jpg',
#  'data/train\\cat.10411.jpg',
#  'data/train\\cat.10412.jpg',
#  'data/train\\cat.10413.jpg',
#  'data/train\\cat.10414.jpg',
#  'data/train\\cat.10415.jpg',
#  'data/train\\cat.10416.jpg',
#  'data/train\\cat.10417.jpg',
#  'data/train\\cat.10418.jpg',
#  'data/train\\cat.10419.jpg',
#  'data/train\\cat.1042.jpg',
#  'data/train\\cat.10420.jpg',
#  'data/train\\cat.10421.jpg',
#  'data/train\\cat.10422.jpg',
#  'data/train\\cat.10423.jpg',
#  'data/train\\cat.10424.jpg',
#  'data/train\\cat.10425.jpg',
#  'data/train\\cat.10426.jpg',
#  'data/train\\cat.10427.jpg',
#  'data/train\\cat.10428.jpg',
#  'data/train\\cat.10429.jpg',
#  'data/train\\cat.1043.jpg',
#  'data/train\\cat.10430.jpg',
#  'data/train\\cat.10431.jpg',
#  'data/train\\cat.10432.jpg',
#  'data/train\\cat.10433.jpg',
#  'data/train\\cat.10434.jpg',
#  'data/train\\cat.10435.jpg',
#  'data/train\\cat.10436.jpg',
#  'data/train\\cat.10437.jpg',
#  'data/train\\cat.10438.jpg',
#  'data/train\\cat.10439.jpg',
#  'data/train\\cat.1044.jpg',
#  'data/train\\cat.10440.jpg',
#  'data/train\\cat.10441.jpg',
#  'data/train\\cat.10442.jpg',
#  'data/train\\cat.10443.jpg',
#  'data/train\\cat.10444.jpg',
#  'data/train\\cat.10445.jpg',
#  'data/train\\cat.10446.jpg',
#  'data/train\\cat.10447.jpg',
#  'data/train\\cat.10448.jpg',
#  'data/train\\cat.10449.jpg',
#  'data/train\\cat.1045.jpg',
#  'data/train\\cat.10450.jpg',
#  'data/train\\cat.10451.jpg',
#  'data/train\\cat.10452.jpg',
#  'data/train\\cat.10453.jpg',
#  'data/train\\cat.10454.jpg',
#  'data/train\\cat.10455.jpg',
#  'data/train\\cat.10456.jpg',
#  'data/train\\cat.10457.jpg',
#  'data/train\\cat.10458.jpg',
#  'data/train\\cat.10459.jpg',
#  'data/train\\cat.1046.jpg',
#  'data/train\\cat.10460.jpg',
#  'data/train\\cat.10461.jpg',
#  'data/train\\cat.10462.jpg',
#  'data/train\\cat.10463.jpg',
#  'data/train\\cat.10464.jpg',
#  'data/train\\cat.10465.jpg',
#  'data/train\\cat.10466.jpg',
#  'data/train\\cat.10467.jpg',
#  'data/train\\cat.10468.jpg',
#  'data/train\\cat.10469.jpg',
#  'data/train\\cat.1047.jpg',
#  'data/train\\cat.10470.jpg',
#  'data/train\\cat.10471.jpg',
#  'data/train\\cat.10472.jpg',
#  'data/train\\cat.10473.jpg',
#  'data/train\\cat.10474.jpg',
#  'data/train\\cat.10475.jpg',
#  'data/train\\cat.10476.jpg',
#  'data/train\\cat.10477.jpg',
#  'data/train\\cat.10478.jpg',
#  'data/train\\cat.10479.jpg',
#  'data/train\\cat.1048.jpg',
#  'data/train\\cat.10480.jpg',
#  'data/train\\cat.10481.jpg',
#  'data/train\\cat.10482.jpg',
#  'data/train\\cat.10483.jpg',
#  'data/train\\cat.10484.jpg',
#  'data/train\\cat.10485.jpg',
#  'data/train\\cat.10486.jpg',
#  'data/train\\cat.10487.jpg',
#  'data/train\\cat.10488.jpg',
#  'data/train\\cat.10489.jpg',
#  'data/train\\cat.1049.jpg',
#  'data/train\\cat.10490.jpg',
#  'data/train\\cat.10491.jpg',
#  'data/train\\cat.10492.jpg',
#  'data/train\\cat.10493.jpg',
#  'data/train\\cat.10494.jpg',
#  'data/train\\cat.10495.jpg',
#  'data/train\\cat.10496.jpg',
#  'data/train\\cat.10497.jpg',
#  'data/train\\cat.10498.jpg',
#  'data/train\\cat.10499.jpg',
#  'data/train\\cat.105.jpg',
#  'data/train\\cat.1050.jpg',
#  'data/train\\cat.10500.jpg',
#  'data/train\\cat.10501.jpg',
#  'data/train\\cat.10502.jpg',
#  'data/train\\cat.10503.jpg',
#  'data/train\\cat.10504.jpg',
#  'data/train\\cat.10505.jpg',
#  'data/train\\cat.10506.jpg',
#  'data/train\\cat.10507.jpg',
#  'data/train\\cat.10508.jpg',
#  'data/train\\cat.10509.jpg',
#  'data/train\\cat.1051.jpg',
#  'data/train\\cat.10510.jpg',
#  'data/train\\cat.10511.jpg',
#  'data/train\\cat.10512.jpg',
#  'data/train\\cat.10513.jpg',
#  'data/train\\cat.10514.jpg',
#  'data/train\\cat.10515.jpg',
#  'data/train\\cat.10516.jpg',
#  'data/train\\cat.10517.jpg',
#  'data/train\\cat.10518.jpg',
#  'data/train\\cat.10519.jpg',
#  'data/train\\cat.1052.jpg',
#  'data/train\\cat.10520.jpg',
#  'data/train\\cat.10521.jpg',
#  'data/train\\cat.10522.jpg',
#  'data/train\\cat.10523.jpg',
#  'data/train\\cat.10524.jpg',
#  'data/train\\cat.10525.jpg',
#  'data/train\\cat.10526.jpg',
#  'data/train\\cat.10527.jpg',
#  'data/train\\cat.10528.jpg',
#  'data/train\\cat.10529.jpg',
#  'data/train\\cat.1053.jpg',
#  'data/train\\cat.10530.jpg',
#  'data/train\\cat.10531.jpg',
#  'data/train\\cat.10532.jpg',
#  'data/train\\cat.10533.jpg',
#  'data/train\\cat.10534.jpg',
#  'data/train\\cat.10535.jpg',
#  'data/train\\cat.10536.jpg',
#  'data/train\\cat.10537.jpg',
#  'data/train\\cat.10538.jpg',
#  'data/train\\cat.10539.jpg',
#  'data/train\\cat.1054.jpg',
#  'data/train\\cat.10540.jpg',
#  'data/train\\cat.10541.jpg',
#  'data/train\\cat.10542.jpg',
#  'data/train\\cat.10543.jpg',
#  'data/train\\cat.10544.jpg',
#  'data/train\\cat.10545.jpg',
#  'data/train\\cat.10546.jpg',
#  'data/train\\cat.10547.jpg',
#  'data/train\\cat.10548.jpg',
#  'data/train\\cat.10549.jpg',
#  'data/train\\cat.1055.jpg',
#  'data/train\\cat.10550.jpg',
#  'data/train\\cat.10551.jpg',
#  'data/train\\cat.10552.jpg',
#  'data/train\\cat.10553.jpg',
#  'data/train\\cat.10554.jpg',
#  'data/train\\cat.10555.jpg',
#  'data/train\\cat.10556.jpg',
#  'data/train\\cat.10557.jpg',
#  'data/train\\cat.10558.jpg',
#  'data/train\\cat.10559.jpg',
#  'data/train\\cat.1056.jpg',
#  'data/train\\cat.10560.jpg',
#  'data/train\\cat.10561.jpg',
#  'data/train\\cat.10562.jpg',
#  'data/train\\cat.10563.jpg',
#  'data/train\\cat.10564.jpg',
#  'data/train\\cat.10565.jpg',
#  'data/train\\cat.10566.jpg',
#  'data/train\\cat.10567.jpg',
#  'data/train\\cat.10568.jpg',
#  'data/train\\cat.10569.jpg',
#  'data/train\\cat.1057.jpg',
#  'data/train\\cat.10570.jpg',
#  'data/train\\cat.10571.jpg',
#  'data/train\\cat.10572.jpg',
#  'data/train\\cat.10573.jpg',
#  'data/train\\cat.10574.jpg',
#  'data/train\\cat.10575.jpg',
#  'data/train\\cat.10576.jpg',
#  'data/train\\cat.10577.jpg',
#  'data/train\\cat.10578.jpg',
#  'data/train\\cat.10579.jpg',
#  'data/train\\cat.1058.jpg',
#  'data/train\\cat.10580.jpg',
#  'data/train\\cat.10581.jpg',
#  'data/train\\cat.10582.jpg',
#  'data/train\\cat.10583.jpg',
#  'data/train\\cat.10584.jpg',
#  'data/train\\cat.10585.jpg',
#  'data/train\\cat.10586.jpg',
#  'data/train\\cat.10587.jpg',
#  'data/train\\cat.10588.jpg',
#  'data/train\\cat.10589.jpg',
#  'data/train\\cat.1059.jpg',
#  'data/train\\cat.10590.jpg',
#  'data/train\\cat.10591.jpg',
#  'data/train\\cat.10592.jpg',
#  'data/train\\cat.10593.jpg',
#  'data/train\\cat.10594.jpg',
#  'data/train\\cat.10595.jpg',
#  'data/train\\cat.10596.jpg',
#  'data/train\\cat.10597.jpg',
#  'data/train\\cat.10598.jpg',
#  'data/train\\cat.10599.jpg',
#  'data/train\\cat.106.jpg',
#  'data/train\\cat.1060.jpg',
#  'data/train\\cat.10600.jpg',
#  'data/train\\cat.10601.jpg',
#  'data/train\\cat.10602.jpg',
#  'data/train\\cat.10603.jpg',
#  'data/train\\cat.10604.jpg',
#  'data/train\\cat.10605.jpg',
#  'data/train\\cat.10606.jpg',
#  'data/train\\cat.10607.jpg',
#  'data/train\\cat.10608.jpg',
#  'data/train\\cat.10609.jpg',
#  'data/train\\cat.1061.jpg',
#  'data/train\\cat.10610.jpg',
#  'data/train\\cat.10611.jpg',
#  'data/train\\cat.10612.jpg',
#  'data/train\\cat.10613.jpg',
#  'data/train\\cat.10614.jpg',
#  'data/train\\cat.10615.jpg',
#  'data/train\\cat.10616.jpg',
#  'data/train\\cat.10617.jpg',
#  'data/train\\cat.10618.jpg',
#  'data/train\\cat.10619.jpg',
#  'data/train\\cat.1062.jpg',
#  'data/train\\cat.10620.jpg',
#  'data/train\\cat.10621.jpg',
#  'data/train\\cat.10622.jpg',
#  'data/train\\cat.10623.jpg',
#  'data/train\\cat.10624.jpg',
#  'data/train\\cat.10625.jpg',
#  'data/train\\cat.10626.jpg',
#  'data/train\\cat.10627.jpg',
#  'data/train\\cat.10628.jpg',
#  'data/train\\cat.10629.jpg',
#  'data/train\\cat.1063.jpg',
#  'data/train\\cat.10630.jpg',
#  'data/train\\cat.10631.jpg',
#  'data/train\\cat.10632.jpg',
#  'data/train\\cat.10633.jpg',
#  'data/train\\cat.10634.jpg',
#  'data/train\\cat.10635.jpg',
#  'data/train\\cat.10636.jpg',
#  'data/train\\cat.10637.jpg',
#  'data/train\\cat.10638.jpg',
#  'data/train\\cat.10639.jpg',
#  'data/train\\cat.1064.jpg',
#  'data/train\\cat.10640.jpg',
#  'data/train\\cat.10641.jpg',
#  'data/train\\cat.10642.jpg',
#  'data/train\\cat.10643.jpg',
#  'data/train\\cat.10644.jpg',
#  'data/train\\cat.10645.jpg',
#  'data/train\\cat.10646.jpg',
#  'data/train\\cat.10647.jpg',
#  'data/train\\cat.10648.jpg',
#  'data/train\\cat.10649.jpg',
#  'data/train\\cat.1065.jpg',
#  'data/train\\cat.10650.jpg',
#  'data/train\\cat.10651.jpg',
#  'data/train\\cat.10652.jpg',
#  'data/train\\cat.10653.jpg',
#  'data/train\\cat.10654.jpg',
#  'data/train\\cat.10655.jpg',
#  'data/train\\cat.10656.jpg',
#  'data/train\\cat.10657.jpg',
#  'data/train\\cat.10658.jpg',
#  'data/train\\cat.10659.jpg',
#  'data/train\\cat.1066.jpg',
#  'data/train\\cat.10660.jpg',
#  'data/train\\cat.10661.jpg',
#  'data/train\\cat.10662.jpg',
#  'data/train\\cat.10663.jpg',
#  'data/train\\cat.10664.jpg',
#  'data/train\\cat.10665.jpg',
#  'data/train\\cat.10666.jpg',
#  'data/train\\cat.10667.jpg',
#  'data/train\\cat.10668.jpg',
#  'data/train\\cat.10669.jpg',
#  'data/train\\cat.1067.jpg',
#  'data/train\\cat.10670.jpg',
#  'data/train\\cat.10671.jpg',
#  'data/train\\cat.10672.jpg',
#  'data/train\\cat.10673.jpg',
#  'data/train\\cat.10674.jpg',
#  'data/train\\cat.10675.jpg',
#  'data/train\\cat.10676.jpg',
#  'data/train\\cat.10677.jpg',
#  'data/train\\cat.10678.jpg',
#  'data/train\\cat.10679.jpg',
#  'data/train\\cat.1068.jpg',
#  'data/train\\cat.10680.jpg',
#  'data/train\\cat.10681.jpg',
#  'data/train\\cat.10682.jpg',
#  'data/train\\cat.10683.jpg',
#  'data/train\\cat.10684.jpg',
#  'data/train\\cat.10685.jpg',
#  'data/train\\cat.10686.jpg',
#  'data/train\\cat.10687.jpg',
#  'data/train\\cat.10688.jpg',
#  'data/train\\cat.10689.jpg',
#  'data/train\\cat.1069.jpg',
#  'data/train\\cat.10690.jpg',
#  'data/train\\cat.10691.jpg',
#  'data/train\\cat.10692.jpg',
#  'data/train\\cat.10693.jpg',
#  'data/train\\cat.10694.jpg',
#  'data/train\\cat.10695.jpg',
#  'data/train\\cat.10696.jpg',
#  'data/train\\cat.10697.jpg',
#  'data/train\\cat.10698.jpg',
#  'data/train\\cat.10699.jpg',
#  'data/train\\cat.107.jpg',
#  'data/train\\cat.1070.jpg',
#  'data/train\\cat.10700.jpg',
#  'data/train\\cat.10701.jpg',
#  'data/train\\cat.10702.jpg',
#  'data/train\\cat.10703.jpg',
#  'data/train\\cat.10704.jpg',
#  'data/train\\cat.10705.jpg',
#  'data/train\\cat.10706.jpg',
#  'data/train\\cat.10707.jpg',
#  'data/train\\cat.10708.jpg',
#  'data/train\\cat.10709.jpg',
#  'data/train\\cat.1071.jpg',
#  'data/train\\cat.10710.jpg',
#  'data/train\\cat.10711.jpg',
#  'data/train\\cat.10712.jpg',
#  'data/train\\cat.10713.jpg',
#  'data/train\\cat.10714.jpg',
#  'data/train\\cat.10715.jpg',
#  'data/train\\cat.10716.jpg',
#  'data/train\\cat.10717.jpg',
#  'data/train\\cat.10718.jpg',
#  'data/train\\cat.10719.jpg',
#  'data/train\\cat.1072.jpg',
#  'data/train\\cat.10720.jpg',
#  'data/train\\cat.10721.jpg',
#  'data/train\\cat.10722.jpg',
#  'data/train\\cat.10723.jpg',
#  'data/train\\cat.10724.jpg',
#  'data/train\\cat.10725.jpg',
#  'data/train\\cat.10726.jpg',
#  'data/train\\cat.10727.jpg',
#  'data/train\\cat.10728.jpg',
#  'data/train\\cat.10729.jpg',
#  'data/train\\cat.1073.jpg',
#  'data/train\\cat.10730.jpg',
#  'data/train\\cat.10731.jpg',
#  'data/train\\cat.10732.jpg',
#  'data/train\\cat.10733.jpg',
#  'data/train\\cat.10734.jpg',
#  'data/train\\cat.10735.jpg',
#  'data/train\\cat.10736.jpg',
#  'data/train\\cat.10737.jpg',
#  'data/train\\cat.10738.jpg',
#  'data/train\\cat.10739.jpg',
#  'data/train\\cat.1074.jpg',
#  'data/train\\cat.10740.jpg',
#  'data/train\\cat.10741.jpg',
#  'data/train\\cat.10742.jpg',
#  'data/train\\cat.10743.jpg',
#  'data/train\\cat.10744.jpg',
#  'data/train\\cat.10745.jpg',
#  'data/train\\cat.10746.jpg',
#  'data/train\\cat.10747.jpg',
#  'data/train\\cat.10748.jpg',
#  'data/train\\cat.10749.jpg',
#  'data/train\\cat.1075.jpg',
#  'data/train\\cat.10750.jpg',
#  'data/train\\cat.10751.jpg',
#  'data/train\\cat.10752.jpg',
#  'data/train\\cat.10753.jpg',
#  'data/train\\cat.10754.jpg',
#  'data/train\\cat.10755.jpg',
#  'data/train\\cat.10756.jpg',
#  'data/train\\cat.10757.jpg',
#  'data/train\\cat.10758.jpg',
#  'data/train\\cat.10759.jpg',
#  'data/train\\cat.1076.jpg',
#  'data/train\\cat.10760.jpg',
#  'data/train\\cat.10761.jpg',
#  'data/train\\cat.10762.jpg',
#  'data/train\\cat.10763.jpg',
#  'data/train\\cat.10764.jpg',
#  'data/train\\cat.10765.jpg',
#  'data/train\\cat.10766.jpg',
#  'data/train\\cat.10767.jpg',
#  'data/train\\cat.10768.jpg',
#  'data/train\\cat.10769.jpg',
#  'data/train\\cat.1077.jpg',
#  'data/train\\cat.10770.jpg',
#  'data/train\\cat.10771.jpg',
#  'data/train\\cat.10772.jpg',
#  'data/train\\cat.10773.jpg',
#  'data/train\\cat.10774.jpg',
#  'data/train\\cat.10775.jpg',
#  'data/train\\cat.10776.jpg',
#  'data/train\\cat.10777.jpg',
#  'data/train\\cat.10778.jpg',
#  'data/train\\cat.10779.jpg',
#  'data/train\\cat.1078.jpg',
#  'data/train\\cat.10780.jpg',
#  'data/train\\cat.10781.jpg',
#  'data/train\\cat.10782.jpg',
#  'data/train\\cat.10783.jpg',
#  'data/train\\cat.10784.jpg',
#  'data/train\\cat.10785.jpg',
#  'data/train\\cat.10786.jpg',
#  'data/train\\cat.10787.jpg',
#  'data/train\\cat.10788.jpg',
#  'data/train\\cat.10789.jpg',
#  'data/train\\cat.1079.jpg',
#  'data/train\\cat.10790.jpg',
#  'data/train\\cat.10791.jpg',
#  'data/train\\cat.10792.jpg',
#  'data/train\\cat.10793.jpg',
#  'data/train\\cat.10794.jpg',
#  'data/train\\cat.10795.jpg',
#  'data/train\\cat.10796.jpg',
#  'data/train\\cat.10797.jpg',
#  'data/train\\cat.10798.jpg',
#  'data/train\\cat.10799.jpg',
#  'data/train\\cat.108.jpg',
#  'data/train\\cat.1080.jpg',
#  'data/train\\cat.10800.jpg',
#  'data/train\\cat.10801.jpg',
#  'data/train\\cat.10802.jpg',
#  'data/train\\cat.10803.jpg',
#  'data/train\\cat.10804.jpg',
#  'data/train\\cat.10805.jpg',
#  'data/train\\cat.10806.jpg',
#  'data/train\\cat.10807.jpg',
#  'data/train\\cat.10808.jpg',
#  'data/train\\cat.10809.jpg',
#  'data/train\\cat.1081.jpg',
#  'data/train\\cat.10810.jpg',
#  'data/train\\cat.10811.jpg',
#  'data/train\\cat.10812.jpg',
#  'data/train\\cat.10813.jpg',
#  'data/train\\cat.10814.jpg',
#  'data/train\\cat.10815.jpg',
#  'data/train\\cat.10816.jpg',
#  'data/train\\cat.10817.jpg',
#  'data/train\\cat.10818.jpg',
#  'data/train\\cat.10819.jpg',
#  'data/train\\cat.1082.jpg',
#  'data/train\\cat.10820.jpg',
#  'data/train\\cat.10821.jpg',
#  'data/train\\cat.10822.jpg',
#  'data/train\\cat.10823.jpg',
#  'data/train\\cat.10824.jpg',
#  'data/train\\cat.10825.jpg',
#  'data/train\\cat.10826.jpg',
#  'data/train\\cat.10827.jpg',
#  'data/train\\cat.10828.jpg',
#  'data/train\\cat.10829.jpg',
#  'data/train\\cat.1083.jpg',
#  'data/train\\cat.10830.jpg',
#  'data/train\\cat.10831.jpg',
#  'data/train\\cat.10832.jpg',
#  'data/train\\cat.10833.jpg',
#  'data/train\\cat.10834.jpg',
#  'data/train\\cat.10835.jpg',
#  'data/train\\cat.10836.jpg',
#  'data/train\\cat.10837.jpg',
#  'data/train\\cat.10838.jpg',
#  'data/train\\cat.10839.jpg',
#  'data/train\\cat.1084.jpg',
#  'data/train\\cat.10840.jpg',
#  'data/train\\cat.10841.jpg',
#  'data/train\\cat.10842.jpg',
#  'data/train\\cat.10843.jpg',
#  'data/train\\cat.10844.jpg',
#  'data/train\\cat.10845.jpg',
#  'data/train\\cat.10846.jpg',
#  'data/train\\cat.10847.jpg',
#  'data/train\\cat.10848.jpg',
#  'data/train\\cat.10849.jpg',
#  'data/train\\cat.1085.jpg',
#  'data/train\\cat.10850.jpg',
#  'data/train\\cat.10851.jpg',
#  'data/train\\cat.10852.jpg',
#  'data/train\\cat.10853.jpg',
#  'data/train\\cat.10854.jpg',
#  'data/train\\cat.10855.jpg',
#  'data/train\\cat.10856.jpg',
#  'data/train\\cat.10857.jpg',
#  'data/train\\cat.10858.jpg',
#  'data/train\\cat.10859.jpg',
#  'data/train\\cat.1086.jpg',
#  'data/train\\cat.10860.jpg',
#  'data/train\\cat.10861.jpg',
#  'data/train\\cat.10862.jpg',
#  'data/train\\cat.10863.jpg',
#  'data/train\\cat.10864.jpg',
#  'data/train\\cat.10865.jpg',
#  'data/train\\cat.10866.jpg',
#  'data/train\\cat.10867.jpg',
#  'data/train\\cat.10868.jpg',
#  'data/train\\cat.10869.jpg',
#  'data/train\\cat.1087.jpg',
#  'data/train\\cat.10870.jpg',
#  'data/train\\cat.10871.jpg',
#  'data/train\\cat.10872.jpg',
#  'data/train\\cat.10873.jpg',
#  'data/train\\cat.10874.jpg',
#  'data/train\\cat.10875.jpg',
#  'data/train\\cat.10876.jpg',
#  'data/train\\cat.10877.jpg',
#  'data/train\\cat.10878.jpg',
#  'data/train\\cat.10879.jpg',
#  'data/train\\cat.1088.jpg',
#  'data/train\\cat.10880.jpg',
#  'data/train\\cat.10881.jpg',
#  'data/train\\cat.10882.jpg',
#  'data/train\\cat.10883.jpg',
#  'data/train\\cat.10884.jpg',
#  'data/train\\cat.10885.jpg',
#  'data/train\\cat.10886.jpg',
#  'data/train\\cat.10887.jpg',
#  'data/train\\cat.10888.jpg',
#  'data/train\\cat.10889.jpg',
#  'data/train\\cat.1089.jpg',
#  'data/train\\cat.10890.jpg',
#  'data/train\\cat.10891.jpg',
#  'data/train\\cat.10892.jpg',
#  'data/train\\cat.10893.jpg',
#  'data/train\\cat.10894.jpg',
#  'data/train\\cat.10895.jpg',
#  'data/train\\cat.10896.jpg',
#  'data/train\\cat.10897.jpg',
#  ...]

# %%
labels = [path.split('/')[-1].split('.')[0] for path in train_list]

# %% [markdown]
# ## Random Plots

# %%
random_idx = np.random.randint(1, len(train_list), size=9)
fig, axes = plt.subplots(3, 3, figsize=(16, 12))

for idx, ax in enumerate(axes.ravel()):
    img = Image.open(train_list[idx])
    ax.set_title(labels[idx])
    ax.imshow(img)

# %% [markdown]
# ## Split

# %%
train_list, valid_list = train_test_split(train_list, 
                                          test_size=0.2,
                                          stratify=labels,
                                          random_state=seed)

# %%
print(f"Train Data: {len(train_list)}")
print(f"Validation Data: {len(valid_list)}")
print(f"Test Data: {len(test_list)}")
# Out:
# Train Data: 20000
# Validation Data: 5000
# Test Data: 12500

# %% [markdown]
# ## Image Augumentation

# %%
train_transforms = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

val_transforms = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
    ]
)


test_transforms = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
    ]
)

# %% [markdown]
# ## Load Datasets

# %%
class CatsDogsDataset(Dataset):
    def __init__(self, file_list, transform=None):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        self.filelength = len(self.file_list)
        return self.filelength

    def __getitem__(self, idx):
        img_path = self.file_list[idx]
        img = Image.open(img_path)
        img_transformed = self.transform(img)

        label = img_path.split("/")[-1].split(".")[0]
        label = 1 if label == "dog" else 0

        return img_transformed, label

# %%
train_data = CatsDogsDataset(train_list, transform=train_transforms)
valid_data = CatsDogsDataset(valid_list, transform=test_transforms)
test_data = CatsDogsDataset(test_list, transform=test_transforms)

# %%
train_loader = DataLoader(dataset = train_data, batch_size=batch_size, shuffle=True )
valid_loader = DataLoader(dataset = valid_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset = test_data, batch_size=batch_size, shuffle=True)

# %%
print(len(train_data), len(train_loader))
# Out:
# 20000 313

# %%
print(len(valid_data), len(valid_loader))
# Out:
# 5000 79

# %% [markdown]
# ## Effecient Attention

# %% [markdown]
# ### Linformer

# %%
efficient_transformer = Linformer(
    dim=128,
    seq_len=49+1,  # 7x7 patches + 1 cls-token
    depth=12,
    heads=8,
    k=64
)

# %% [markdown]
# ### Visual Transformer

# %%
model = ViT(
    dim=128,
    image_size=224,
    patch_size=32,
    num_classes=2,
    transformer=efficient_transformer,
    channels=3,
).to(device)

# %%
import onnx
from onnx_tf.backend import prepare

# %%
# Exporting model to onnx
dummy_input = torch.randn(64, 3, 224, 224)
torch.onnx.export(model, dummy_input, "vit.onnx", opset_version=12,)
onnx_model = onnx.load("vit.onnx")
tf_model = prepare(model)
# Out:
# C:\Users\Lily\AppData\Local\Programs\Python\Python39\lib\site-packages\einops-0.3.2-py3.9.egg\einops\einops.py:179: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   axes_lengths[unknown_axis] = length // known_product
# C:\Users\Lily\AppData\Local\Programs\Python\Python39\lib\site-packages\linformer\linformer.py:97: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert kv_len == self.seq_len, f'the sequence length of the key / values must be {self.seq_len} - {kv_len} given'
# C:\Users\Lily\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\onnx\symbolic_helper.py:325: UserWarning: Type cannot be inferred, which might cause exported graph to produce incorrect results.
#   warnings.warn("Type cannot be inferred, which might cause exported graph to produce incorrect results.")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6040/2579129998.py in <module>
#       3 torch.onnx.export(model, dummy_input, "vit.onnx", opset_version=12,)
#       4 onnx_model = onnx.load("vit.onnx")
# ----> 5 tf_model = prepare(model)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\onnx_tf\backend.py in prepare(cls, model, device, strict, logging_level, auto_cast, **kwargs)
#      65     :returns: A TensorflowRep class object representing the ONNX model
#      66     """
# ---> 67     super(TensorflowBackend, cls).prepare(model, device, **kwargs)
#      68     common.logger.setLevel(logging_level)
#      69     common.logger.handlers[0].setLevel(logging_level)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\onnx\backend\base.py in prepare(cls, model, device, **kwargs)
#      74                 ):  # type: (...) -> Optional[BackendRep]
#      75         # TODO Remove Optional from return type
# ---> 76         onnx.checker.check_model(model)
#      77         return None
#      78
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\onnx\checker.py in check_model(model, full_check)
#      99             onnx.shape_inference.infer_shapes_path(model, check_type=True, strict_mode=True)
#     100     else:
# --> 101         protobuf_string = model if isinstance(model, binary_type) else model.SerializeToString()
#     102         # If the protobuf is larger than 2GB,
#     103         # remind users should use the model path to check
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#    1175             if name in modules:
#    1176                 return modules[name]
# -> 1177         raise AttributeError("'{}' object has no attribute '{}'".format(
#    1178             type(self).__name__, name))
#    1179
#
# AttributeError: 'ViT' object has no attribute 'SerializeToString'

# %% [markdown]
# ### Training

# %%
# loss function
criterion = nn.CrossEntropyLoss()
# optimizer
optimizer = optim.Adam(model.parameters(), lr=lr)
# scheduler
scheduler = StepLR(optimizer, step_size=1, gamma=gamma)

# %%
for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0

    for data, label in tqdm(train_loader):
        data = data.to(device)
        label = label.to(device)

        output = model(data)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += acc / len(train_loader)
        epoch_loss += loss / len(train_loader)

    with torch.no_grad():
        epoch_val_accuracy = 0
        epoch_val_loss = 0
        for data, label in valid_loader:
            data = data.to(device)
            label = label.to(device)

            val_output = model(data)
            val_loss = criterion(val_output, label)

            acc = (val_output.argmax(dim=1) == label).float().mean()
            epoch_val_accuracy += acc / len(valid_loader)
            epoch_val_loss += val_loss / len(valid_loader)

    print(
        f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - acc: {epoch_accuracy:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f}\n"
    )
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
